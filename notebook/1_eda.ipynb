# %%
from izlearn.vision import ImageExplorer
import numpy as np
image_dir = ImageExplorer('data')
image_dir.show_summary()

# %%
print(image_dir.class_names)
print(np.bincount(image_dir.labels))
# Out:
# {0: 'AK', 1: 'KAPADOKYA', 2: 'SIRA', 3: 'NURLU'}
# [401 465 384 306]

# %%
image_dir.show_class_distribution()

# %%
image_dir.show_sample_images((10,10), 4, 3)
